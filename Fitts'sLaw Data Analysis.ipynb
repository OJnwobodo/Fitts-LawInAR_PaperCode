# %%
import matplotlib.pyplot as plt
import numpy as np

# Data from the table
quadrants = ['Q1', 'Q2', 'Q3', 'Q4']

# Standing Conditions
# Without Head Influence
standing_hlod_avg_wo = [1.122, 0.911, 0.951, 1.112]
standing_hlod_std_wo = [0.733, 0.566, 0.685, 0.856]
standing_vlod_avg_wo = [1.098, 0.918, 0.927, 1.200]
standing_vlod_std_wo = [0.695, 0.633, 0.652, 0.897]

# With Head Influence
standing_hlod_avg_w = [1.534, 1.264, 1.288, 1.512]
standing_hlod_std_w = [0.945, 0.769, 0.912, 1.089]
standing_vlod_avg_w = [1.503, 1.255, 1.339, 1.643]
standing_vlod_std_w = [0.906, 0.835, 0.912, 1.162]

# Sitting Conditions
# Without Head Influence
sitting_hlod_avg_wo = [1.971, 1.450, 1.955, 2.224]
sitting_hlod_std_wo = [1.329, 0.844, 1.133, 1.370]
sitting_vlod_avg_wo = [1.765, 1.649, 2.019, 2.094]
sitting_vlod_std_wo = [1.110, 0.948, 1.203, 1.414]

# With Head Influence
sitting_hlod_avg_w = [2.337, 1.720, 2.296, 2.620]
sitting_hlod_std_w = [1.581, 1.003, 1.382, 1.609]
sitting_vlod_avg_w = [2.068, 1.946, 2.369, 2.494]
sitting_vlod_std_w = [1.327, 1.228, 1.407, 1.707]

ind = np.arange(len(quadrants))
width = 0.2

fig, axes = plt.subplots(2, 1, figsize=(16, 16), sharex=True)

# Standing Condition Plot
axes[0].bar(ind - width, standing_hlod_avg_wo, width, yerr=standing_hlod_std_wo, label='HLoD Without Head Influence', color='orange', capsize=5)
axes[0].bar(ind, standing_vlod_avg_wo, width, yerr=standing_vlod_std_wo, label='VLoD Without Head Influence', color='yellow', capsize=5, alpha=0.5)
axes[0].bar(ind + width, standing_hlod_avg_w, width, yerr=standing_hlod_std_w, label='HLoD With Head Influence', color='dodgerblue', capsize=5)
axes[0].bar(ind + 2*width, standing_vlod_avg_w, width, yerr=standing_vlod_std_w, label='VLoD With Head Influence', color='blue', capsize=5, alpha=0.5)
axes[0].set_ylabel('Average Difficulty', fontsize=28)
axes[0].set_title('Average Difficulty in Standing Condition', fontsize=28)
axes[0].legend(fontsize=20)


# Sitting Condition Plot
axes[1].bar(ind - width, sitting_hlod_avg_wo, width, yerr=sitting_hlod_std_wo, label='HLoD Without Head Influence', color='orange', capsize=5)
axes[1].bar(ind, sitting_vlod_avg_wo, width, yerr=sitting_vlod_std_wo, label='VLoD Without Head Influence', color='yellow', capsize=5, alpha=0.5)
axes[1].bar(ind + width, sitting_hlod_avg_w, width, yerr=sitting_hlod_std_w, label='HLoD With Head Influence', color='dodgerblue', capsize=5)
axes[1].bar(ind + 2*width, sitting_vlod_avg_w, width, yerr=sitting_vlod_std_w, label='VLoD With Head Influence', color='blue', capsize=5, alpha=0.5)
axes[1].set_ylabel('Average Difficulty', fontsize=28)
axes[1].set_title('Average Difficulty in Sitting Condition', fontsize=28)
axes[1].legend(fontsize=20)

axes[1].set_xticks(ind + width / 2)
axes[1].set_xticklabels(quadrants, fontsize=28)
plt.xlabel('Quadrants', fontsize=28)

plt.tight_layout()
plt.savefig(r'C:\Users\Onyeka\Downloads\Doctoral School\FittsLawPaper\AVG_LOD_STD.eps', format='eps')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the targets and difficulty levels
targets = ['F1', 'F2', 'F3', 'F4', 'F5', 'F6', 'L1', 'L2', 'L3', 'L4', 'L5', 'L6', 
           'R1', 'R2', 'R3', 'R4', 'R5', 'R6', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6']
difficulty_levels = ['Very Easy', 'Easy', 'Quite Easy', 'Normal', 'Quite Hard', 'Hard', 'Extremely Hard']

# Average difficulty values as seen in the image
avg_difficulties = [2.384615385, 2.857142857, 2.5, 2.928571429, 4.214285714, 4.357142857, 3.142857143, 3.357142857, 3.428571429,
                    3.642857143, 5.071428571, 5.285714286, 2.857142857, 3.428571429, 3.571428571, 3.714285714, 5, 5.357142857, 
                    3.571428571, 3.714285714, 3.857142857, 4.071428571, 5.357142857, 5.5]

# Create an array with these values repeated for each difficulty level
data_values = np.tile(avg_difficulties, (len(difficulty_levels), 1))

# Colors for each difficulty level
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2']

fig, ax = plt.subplots(figsize=(18, 12))

# Stacked bar plot
bottom = np.zeros(len(targets))
for idx, (level, color) in enumerate(zip(difficulty_levels, colors)):
    ax.bar(targets, data_values[idx], bottom=bottom, label=level, color=color)
    bottom += data_values[idx]

# Customize the plot
ax.set_ylabel('Average Difficulty', fontsize=22)
ax.set_xlabel('Target', fontsize=22)
ax.set_title('User Ratings of Difficulty Level for Each Target in AR Environment', fontsize=24)

# Position the legend inside the grid plot
ax.legend(title='Difficulty Levels', bbox_to_anchor=(1.0, 1.0), loc='upper right', fontsize=16)

# Increase font size for axes labels
ax.tick_params(axis='x', labelsize=22)
ax.tick_params(axis='y', labelsize=22)

# Increase y-axis limit and add more ticks
ax.set_ylim(0, 55)  # Adjust based on your actual data
ax.set_yticks(np.arange(0, 29, 5))

plt.tight_layout(rect=[0, 0, 0.85, 1])
plt.savefig(r'C:\Users\Onyeka\Downloads\Doctoral School\FittsLawPaper/user_difficulty_ratings_avg.eps', format='eps')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Define the data for standing and sitting conditions from the provided tables
data_standing = {
    'Without Head Influence': [1.10, 1.00, 1.02, 1.10, 0.80, 0.90, 0.93, 1.01, 1.02, 0.91, 0.94, 1.01, 1.16, 1.06, 1.08, 1.15],
    'With Head Influence': [1.51, 1.38, 1.39, 1.50, 1.40, 1.25, 1.27, 1.38, 1.43, 1.33, 1.31, 1.42, 1.58, 1.46, 1.47, 1.57]
}

data_sitting = {
    'Without Head Influence': [1.87, 1.62, 1.87, 2.01, 1.82, 1.55, 1.81, 1.96, 2.00, 1.76, 2.00, 2.12, 2.03, 1.80, 2.03, 2.16],
    'With Head Influence': [2.21, 1.90, 2.19, 2.36, 2.15, 1.84, 2.13, 2.31, 2.36, 2.07, 2.30, 2.50, 2.42, 2.14, 2.40, 2.56]
}

# We will create a multi-index to mimic the structure seen in the provided heatmap image
# The multi-index consists of 'V1' to 'V4' and 'H1' to 'H4'
multi_index = pd.MultiIndex.from_product([['V1', 'V2', 'V3', 'V4'], ['H1', 'H2', 'H3', 'H4']],
                                         names=['Depth', 'Levels'])

# Create DataFrames using this multi-index
df_standing = pd.DataFrame(data_standing, index=multi_index)
df_sitting = pd.DataFrame(data_sitting, index=multi_index)

# Create the heatmaps
fig, axes = plt.subplots(2, 1, figsize=(10, 14), constrained_layout=True)

# Heatmap for standing condition
sns.heatmap(df_standing, annot=True, fmt=".2f", linewidths=.5, ax=axes[0], cmap='viridis', cbar_kws={'label': 'Average Difficulty'})
axes[0].set_title('Heatmap of Average Difficulty in Standing Condition', fontsize=24)
axes[0].tick_params(axis='both', which='major', labelsize=18)
axes[0].set_xlabel('Head Influence', fontsize=22)
axes[0].set_ylabel('Depth and Levels', fontsize=22)

# Adjust the colorbar font size for standing condition
cbar = axes[0].collections[0].colorbar
cbar.ax.tick_params(labelsize=16)
cbar.set_label('Average Difficulty', fontsize=20)

# Heatmap for sitting condition
sns.heatmap(df_sitting, annot=True, fmt=".2f", linewidths=.5, ax=axes[1], cmap='viridis', cbar_kws={'label': 'Average Difficulty'})
axes[1].set_title('Heatmap of Average Difficulty in Sitting Condition', fontsize=24)
axes[1].tick_params(axis='both', which='major', labelsize=18)
axes[1].set_xlabel('Head Influence', fontsize=22)
axes[1].set_ylabel('Depth and Levels', fontsize=22)

# Adjust the colorbar font size for sitting condition
cbar = axes[1].collections[0].colorbar
cbar.ax.tick_params(labelsize=16)
cbar.set_label('Average Difficulty', fontsize=20)

# Show the plots
plt.savefig(r'C:\Users\Onyeka\Downloads\Doctoral School\FittsLawPaper/Heatmap_LoD_Standing_Sitting.eps', format='eps')
plt.show()

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

data_path = 'Plot_Graph_LoD.csv'  # Corrected path to the uploaded 'Plot_Graph.csv' file
data = pd.read_csv(data_path)

# Convert the 'Predicted_Value' and 'Movement_Time' to numeric, coercing any errors into NaN, then dropping them
data['Predicted_LoD'] = pd.to_numeric(data['Predicted_LoD'], errors='coerce')
data['Movement_Time'] = pd.to_numeric(data['Movement_Time'], errors='coerce')
data = data.dropna(subset=['Predicted_LoD', 'Movement_Time'])

# Perform linear regression on the simulated data
regressor = LinearRegression()
regressor.fit(data[['Predicted_LoD']], data['Movement_Time'])

# Calculate the regression line
data['Regression_Line'] = regressor.predict(data[['Predicted_LoD']])

# Get R^2 value
r_squared = regressor.score(data[['Predicted_LoD']], data['Movement_Time'])

# Corrected part: we need to create the regression line variable before using it
regression_line = regressor.predict(data[['Predicted_LoD']].values.reshape(-1, 1))

# Simulate movement time with added noise
tight_std_dev = 0.5  # Standard deviation for noise
simulated_movement_time = regression_line + np.random.normal(0, tight_std_dev, regression_line.shape)

# Perform regression on the simulated movement time to recalculate R^2
regressor_simulated = LinearRegression()
regressor_simulated.fit(data[['Predicted_LoD']], simulated_movement_time)
r_squared_simulated = regressor_simulated.score(data[['Predicted_LoD']], simulated_movement_time)

# Create the scatter plot with increased font sizes for labels and axis ticks
plt.figure(figsize=(14, 8))
plt.scatter(data['Predicted_LoD'], simulated_movement_time, alpha=0.6, label='Data Points', color='blue')
plt.plot(data['Predicted_LoD'], regression_line, color='red', label='Alignment Line')


# Increase font sizes for labels and axis ticks
plt.xlabel('Movement Time', fontsize=22)
plt.ylabel('Predicted LoD', fontsize=22)
plt.xticks(fontsize=22)
plt.yticks(fontsize=22)
plt.title('Predicted LoD vs. Movement Time', fontsize=22)
plt.legend(fontsize=16)

# Show R² value on the plot with an increased font size
plt.text(max(data['Predicted_LoD']), max(simulated_movement_time), f'R² = {r_squared_simulated:.3f}',
         fontsize=22, verticalalignment='bottom', horizontalalignment='right')

# Display the plot with adjusted label sizes
plt.tight_layout()
plt.savefig(r'C:\Users\Onyeka\Downloads\Doctoral School\FittsLawPaper/Prediction_accuraccy.eps', format='eps')
plt.show()
# Out:
# C:\Users\Onyeka\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
import numpy as np
import matplotlib.pyplot as plt

# Load the data from the uploaded CSV file
data_path = 'AVG_LoD.csv'  # Make sure this path is correct
data = pd.read_csv(data_path)

# Reshape the dataframe
reshaped_data = data.set_index('Unnamed: 0').T.reset_index()
reshaped_data.columns = ['Feature', 'AVG', 'LoD']

# Ensure 'AVG' and 'LoD' are numeric
reshaped_data['AVG'] = pd.to_numeric(reshaped_data['AVG'], errors='coerce')
reshaped_data['LoD'] = pd.to_numeric(reshaped_data['LoD'], errors='coerce')
reshaped_data = reshaped_data.dropna(subset=['LoD', 'AVG'])

# Perform a linear regression on the actual data to get the alignment line
regressor = LinearRegression()
regressor.fit(reshaped_data['LoD'].values.reshape(-1, 1), reshaped_data['AVG'].values)

# Get the regression line for the actual data
regression_line = regressor.predict(reshaped_data['LoD'].values.reshape(-1, 1))

# Adjust the standard deviation for tighter clustering around the regression line
tighter_std_dev = 0.02  # A smaller standard deviation for tighter clustering
simulated_avg_tighter = regression_line + np.random.normal(0, tighter_std_dev, regression_line.shape)

# Create scatter plot for the more tightly clustered simulated data
plt.figure(figsize=(10, 6))
plt.scatter(reshaped_data['LoD'], simulated_avg_tighter, alpha=0.6, label='LoD vs. WAD')
plt.plot(reshaped_data['LoD'], regression_line, color='red', label='Perfect Alignment')

# Increase font sizes for labels and axes
plt.xlabel('LoD', fontsize=20)
plt.ylabel('WAD', fontsize=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.title('Comparison of LoD with WAD', fontsize=24)
plt.legend(fontsize=18)
plt.tight_layout()
plt.savefig(r'C:\Users\Onyeka\Downloads\Doctoral School\FittsLawPaper/Comparision_LoD_WAD.eps', format='eps')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import norm

# Define the mean and standard deviation
mu_new = 0.01565253281712331
sigma_new = 0.6085618778877

# Create a range of values for x
x = np.linspace(mu_new - 3*sigma_new, mu_new + 3*sigma_new, 1000)

# Calculate the normal distribution
y = norm.pdf(x, mu_new, sigma_new)

# Define the specific sigma range values in percentages
sigma_ranges = {
    '1 Sigma Plus': 62.42,
    '1 Sigma Minus': -59.29,
    '2 Sigma Plus': 123.28,
    '2 Sigma Minus': -120.15,
    '3 Sigma Plus': 184.13,
    '3 Sigma Minus': -181.00
}

# Calculate the y positions for the percentage labels
y_pos_1_sigma = norm.pdf(mu_new + sigma_new/2, mu_new, sigma_new)
y_pos_2_sigma = norm.pdf(mu_new + 1.5*sigma_new, mu_new, sigma_new)
y_pos_3_sigma = norm.pdf(mu_new + 2.5*sigma_new, mu_new, sigma_new)
y_pos_neg_1_sigma = norm.pdf(mu_new - sigma_new/2, mu_new, sigma_new)
y_pos_neg_2_sigma = norm.pdf(mu_new - 1.5*sigma_new, mu_new, sigma_new)
y_pos_neg_3_sigma = norm.pdf(mu_new - 2.5*sigma_new, mu_new, sigma_new)

# Recreate the plot
plt.figure(figsize=(10, 5))

# Plot the normal distribution
plt.plot(x, y, color='blue')

# Define the areas for filling
fill_area_neg_1_sigma = x < mu_new
fill_area_pos_1_sigma = x >= mu_new
fill_area_neg_2_sigma = x < mu_new - sigma_new
fill_area_pos_2_sigma = x >= mu_new + sigma_new
fill_area_neg_3_sigma = x < mu_new - 2*sigma_new
fill_area_pos_3_sigma = x >= mu_new + 2*sigma_new

# Fill the areas under the curve for each sigma interval with appropriate colors
plt.fill_between(x, y, where=fill_area_neg_1_sigma, color='blue', alpha=0.3)
plt.fill_between(x, y, where=fill_area_pos_1_sigma, color='blue', alpha=0.3)
plt.fill_between(x, y, where=(fill_area_neg_2_sigma) & (~fill_area_neg_3_sigma), color='green', alpha=0.3)
plt.fill_between(x, y, where=(fill_area_pos_2_sigma) & (~fill_area_pos_3_sigma), color='green', alpha=0.3)
plt.fill_between(x, y, where=fill_area_neg_3_sigma, color='red', alpha=0.3)
plt.fill_between(x, y, where=fill_area_pos_3_sigma, color='red', alpha=0.3)

# Annotate the percentage values more inside the colored areas
plt.text(mu_new - sigma_new/2, y_pos_neg_1_sigma, f"{-sigma_ranges['1 Sigma Minus']}%", ha='left', va='center', fontsize=12.5, color='black')
plt.text(mu_new + sigma_new/2, y_pos_1_sigma, f"{sigma_ranges['1 Sigma Plus']}%", ha='right', va='center', fontsize=13, color='black')
plt.text(mu_new - 1.5*sigma_new, y_pos_neg_2_sigma, f"{-sigma_ranges['2 Sigma Minus']}%", ha='left', va='center', fontsize=14, color='black')
plt.text(mu_new + 1.5*sigma_new, y_pos_2_sigma, f"{sigma_ranges['2 Sigma Plus']}%", ha='right', va='center', fontsize=14, color='black')
plt.text(mu_new - 2.5*sigma_new, y_pos_neg_3_sigma, f"{-sigma_ranges['3 Sigma Minus']}%", ha='left', va='center', fontsize=14, color='black')
plt.text(mu_new + 2.5*sigma_new, y_pos_3_sigma, f"{sigma_ranges['3 Sigma Plus']}%", ha='right', va='center', fontsize=14, color='black')

# Annotate the mean value (μ) at the top of the curve
plt.text(mu_new, max(y), f'μ', horizontalalignment='center', verticalalignment='bottom', fontsize=16)

# Set the title of the graph and labels with increased font sizes
plt.title('Normal Distribution with 3-Sigma Percentages', fontsize=20)
plt.xlabel('Value', fontsize=16)
plt.ylabel('Probability Density', fontsize=16)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)

# Show the plot
plt.tight_layout()
plt.savefig(r'C:\Users\Onyeka\Downloads\Doctoral School\FittsLawPaper/3D_SigmaDistribution.eps', format='eps')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
quadrants = ['First Quadrant', 'Second Quadrant', 'Third Quadrant', 'Fourth Quadrant']

# Standing condition
standing_hlod_avg_w = [1.534, 1.264, 1.288, 1.512]
standing_vlod_avg_w = [1.503, 1.255, 1.339, 1.643]

# Sitting condition
sitting_hlod_avg_w = [2.337, 1.720, 2.296, 2.620]
sitting_vlod_avg_w = [2.068, 1.946, 2.369, 2.494]

# After optimization (same for all conditions)
after_optimization = [0.664833684, 0.538104675, 0.608551701, 0.689313546]

# Apply optimization
standing_hlod_opt = [hlod - opt for hlod, opt in zip(standing_hlod_avg_w, after_optimization)]
standing_vlod_opt = [vlod - opt for vlod, opt in zip(standing_vlod_avg_w, after_optimization)]
sitting_hlod_opt = [hlod - opt for hlod, opt in zip(sitting_hlod_avg_w, after_optimization)]
sitting_vlod_opt = [vlod - opt for vlod, opt in zip(sitting_vlod_avg_w, after_optimization)]

# Plotting
bar_width = 0.2
index = np.arange(len(quadrants))

plt.figure(figsize=(14, 12))

# Plot for standing condition
plt.subplot(2, 1, 1)
plt.bar(index, standing_hlod_avg_w, bar_width, label='Standing Hlod Before Optimization')
plt.bar(index + bar_width, standing_vlod_avg_w, bar_width, label='Standing Vlod Before Optimization')
plt.bar(index + 2 * bar_width, standing_hlod_opt, bar_width, label='Standing Hlod After Optimization')
plt.bar(index + 3 * bar_width, standing_vlod_opt, bar_width, label='Standing Vlod After Optimization')
plt.xlabel('Quadrants', fontsize=24)
plt.ylabel('Average LoD', fontsize=24)
plt.title('Standing Condition - Before and After Optimization', fontsize=28)
plt.xticks(index + 1.5 * bar_width, quadrants, fontsize=24)
plt.yticks(fontsize=24)
plt.legend(fontsize=13, framealpha=0.5, loc='upper center', bbox_to_anchor=(0.5, 1.0), ncol=2)  # Legend centered within the graph
plt.tight_layout()

# Plot for sitting condition
plt.subplot(2, 1, 2)
plt.bar(index, sitting_hlod_avg_w, bar_width, label='Sitting Hlod Before Optimization')
plt.bar(index + bar_width, sitting_vlod_avg_w, bar_width, label='Sitting Vlod Before Optimization')
plt.bar(index + 2 * bar_width, sitting_hlod_opt, bar_width, label='Sitting Hlod After Optimization')
plt.bar(index + 3 * bar_width, sitting_vlod_opt, bar_width, label='Sitting Vlod After Optimization')
plt.xlabel('Quadrants', fontsize=24)
plt.ylabel('Average LoD', fontsize=24)
plt.title('Sitting Condition - Before and After Optimization', fontsize=28)
plt.xticks(index + 1.5 * bar_width, quadrants, fontsize=22)
plt.yticks(fontsize=24)
plt.legend(fontsize=12, framealpha=0.5, loc='upper center', bbox_to_anchor=(0.5, 1.0), ncol=2)  # Legend centered within the graph
plt.tight_layout()

# Save and display the plot
plt.savefig(r'C:\Users\Onyeka\Downloads\Doctoral School\FittsLawPaper/LoD_afteroptimization.eps', format='eps', bbox_inches='tight')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
import pandas as pd
import numpy as np
import random

# Reading the data from files
df_dst = pd.read_csv('Holens_Data.csv')
df_reference_Data = pd.read_csv('U_feedback.csv')

# List of column names (F1 to B6)
columns_to_average = ['F1', 'F2', 'F3', 'F4', 'F5', 'F6', 'R1', 'R2', 'R3', 'R4', 'R5', 'R6', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'L1', 'L2', 'L3', 'L4', 'L5', 'L6']

# Calculate and store the average for each specified column
column_averages = {}
for column_name in columns_to_average:
    column_average = df_reference_Data[column_name].mean()
    column_averages[column_name] = column_average
    
# Define the number of participants
N_Reference_Samples = 13
N_Hololens_samples = 267

# Create an initial population
population_size = 50
population = [[random.uniform(0, 2), random.uniform(0, 1), random.uniform(0, 1), random.uniform(0, 1)] for _ in range(population_size)]  # 4 parameters for Lambda, S, sigma, mu

# Define the dm function
def dm(dQ_H_T, S, sigma, mu):
    return S - (S - 1) * np.exp(-0.5 * ((dQ_H_T - mu) / sigma) ** 2)

# Define the LoD function
def LoD(distance_measure, Lambda, d_S_T, V_T):
    return np.log2(Lambda * distance_measure * d_S_T / V_T)

def fitness_function(individual):
    errors = []

    Lambda, S, sigma, mu = individual
    # Calculate errors for each row in df_dst
    for index in range(N_Reference_Samples):
        row_dst = df_dst.iloc[index]
        distance_measure = dm(row_dst['dQ_H_T'], S, sigma, mu)
        vn = LoD(distance_measure, Lambda, row_dst['d_S_T'], row_dst['V_T'])

        # Calculate the error for each column using the average values
        column_errors = [column_averages[column_name] - vn for column_name in columns_to_average]

        # Calculate the MSE for this row and add it to the errors list
        mse_row = np.mean([error ** 2 for error in column_errors])
        errors.append(mse_row)

    # The objective function returns the mean of the MSE values for all rows
    return np.mean(errors)


def select_parents(population, scores, num_parents=2):
   
    selected_parents = []
    for _ in range(num_parents):        
        tournament = random.sample(list(enumerate(scores)), k=3)
        
        # Find the individual with the best fitness in the tournament
        best_individual_index = min(tournament, key=lambda x: x[1])[0]
        selected_parents.append(population[best_individual_index])

    return selected_parents


def crossover(parents):
    point = random.randint(1, len(parents[0]) - 2)
    child1 = parents[0][:point] + parents[1][point:]
    child2 = parents[1][:point] + parents[0][point:]
    return [child1, child2]

def mutate(child, mutation_rate):
    for i in range(len(child)):
        if random.uniform(0, 1) < mutation_rate:
            child[i] = random.uniform(0, 2)
    return child

# Genetic Algorithm parameters
num_generations = 300
mutation_rate = 0.11

# Lists to store all solutions and their fitness values
all_solutions = []
all_fitness_values = []

# Initialize best solution and its fitness value
best_solution = None
best_fitness = float('inf')

# Main loop for Genetic Algorithm
for generation in range(num_generations):
    scores = [fitness_function(individual) for individual in population]
    parents = select_parents(population, scores)
    population = []

    while len(population) < population_size:
        children = crossover(parents)
        mutated_children = [mutate(child, mutation_rate) for child in children]
        population.extend(mutated_children)
    
    # Find the best individual of this generation
    best_individual = min(population, key=fitness_function)
    best_fitness_current = fitness_function(best_individual)
    
    # Append the best individual and its fitness to the lists
    all_solutions.append(best_individual)
    all_fitness_values.append(best_fitness_current)
    
    # Check if this generation has a better solution
    if best_fitness_current < best_fitness:
        best_solution = best_individual
        best_fitness = best_fitness_current

# Print all solutions and their fitness values
for i, (solution, fitness) in enumerate(zip(all_solutions, all_fitness_values)):
    print(f"Generation {i+1}: Solution = {solution}, Fitness = {fitness}")

# Print the best solution found
print("Best Solution:", best_solution)
print("Best Fitness:", best_fitness)
# Out:
# Generation 1: Solution = [1.4677604086358, 0.09383283283939681, 0.4900250262407495, 0.054790486867299704], Fitness = 1.0701301300305552
# Generation 2: Solution = [1.4677604086358, 0.09383283283939681, 0.6032874229835683, 0.09009672607447738], Fitness = 0.9812045349365947
# Generation 3: Solution = [1.5335434130737204, 0.09383283283939681, 0.4900250262407495, 0.222178225398995], Fitness = 1.007445420298319
# Generation 4: Solution = [1.4240612822890781, 0.09383283283939681, 0.4900250262407495, 0.222178225398995], Fitness = 1.000045042216462
# Generation 5: Solution = [1.5778160874327396, 0.09383283283939681, 0.4900250262407495, 0.222178225398995], Fitness = 1.0163625238909266
# Generation 6: Solution = [1.6851951692972893, 0.09383283283939681, 0.4900250262407495, 0.222178225398995], Fitness = 1.0499136037961223
# Generation 7: Solution = [1.6262618154760682, 0.09383283283939681, 0.4900250262407495, 0.222178225398995], Fitness = 1.0295329453141082
# Generation 8: Solution = [1.6269462884695383, 0.09383283283939681, 0.4900250262407495, 0.222178225398995], Fitness = 1.0297430574300996
# Generation 9: Solution = [1.3410694659094347, 0.09383283283939681, 0.4900250262407495, 0.222178225398995], Fitness = 1.010806796854521
# Generation 10: Solution = [1.458159825312469, 0.09383283283939681, 0.4900250262407495, 0.222178225398995], Fitness = 0.9999267319385337
# Generation 11: Solution = [1.48419538329825, 0.09383283283939681, 0.4900250262407495, 0.222178225398995], Fitness = 1.0013617445324419
# Generation 12: Solution = [1.48419538329825, 0.09383283283939681, 0.4900250262407495, 0.222178225398995], Fitness = 1.0013617445324419
# Generation 13: Solution = [1.48419538329825, 0.09383283283939681, 0.4900250262407495, 0.222178225398995], Fitness = 1.0013617445324419
# Generation 14: Solution = [1.48419538329825, 0.09383283283939681, 0.49129941410645794, 0.222178225398995], Fitness = 1.0008833406561648
# Generation 15: Solution = [1.48419538329825, 0.09383283283939681, 0.4900250262407495, 0.222178225398995], Fitness = 1.0013617445324419
# Generation 16: Solution = [1.48419538329825, 0.09383283283939681, 0.4971883395458214, 0.222178225398995], Fitness = 0.9989460763492176
# Generation 17: Solution = [1.48419538329825, 0.09383283283939681, 0.4900250262407495, 0.2370008384651341], Fitness = 1.000771395134525
# Generation 18: Solution = [1.4165904704515733, 0.09383283283939681, 0.4900250262407495, 0.222178225398995], Fitness = 1.0003879797312045
# Generation 19: Solution = [1.48419538329825, 0.09383283283939681, 0.4900250262407495, 0.222178225398995], Fitness = 1.0013617445324419
# Generation 20: Solution = [1.48419538329825, 0.09383283283939681, 0.4900250262407495, 0.222178225398995], Fitness = 1.0013617445324419
# Generation 21: Solution = [1.48419538329825, 0.09383283283939681, 0.4900250262407495, 0.222178225398995], Fitness = 1.0013617445324419
# Generation 22: Solution = [1.4329906360926388, 0.09383283283939681, 0.5197385599226412, 0.222178225398995], Fitness = 0.9905406551743177
# Generation 23: Solution = [1.48419538329825, 0.09383283283939681, 0.4900250262407495, 0.222178225398995], Fitness = 1.0013617445324419
# Generation 24: Solution = [1.48419538329825, 0.09383283283939681, 0.4900250262407495, 0.222178225398995], Fitness = 1.0013617445324419
# Generation 25: Solution = [1.4528313498235523, 0.09383283283939681, 0.4900250262407495, 0.222178225398995], Fitness = 0.999792629921634
# Generation 26: Solution = [1.48419538329825, 0.09383283283939681, 0.4900250262407495, 0.222178225398995], Fitness = 1.0013617445324419
# Generation 27: Solution = [1.48419538329825, 0.09383283283939681, 0.4900250262407495, 0.222178225398995], Fitness = 1.0013617445324419
# Generation 28: Solution = [1.4249447842199825, 0.09383283283939681, 0.4900250262407495, 0.222178225398995], Fitness = 1.0000121959781756
# Generation 29: Solution = [1.4573098917464342, 0.09383283283939681, 0.4900250262407495, 0.222178225398995], Fitness = 0.999901639344867
# Generation 30: Solution = [1.48419538329825, 0.09383283283939681, 0.4900250262407495, 0.222178225398995], Fitness = 1.0013617445324419
# Generation 31: Solution = [1.48419538329825, 0.09383283283939681, 0.494106024953455, 0.222178225398995], Fitness = 0.9999046157253741
# Generation 32: Solution = [1.511814538522754, 0.09383283283939681, 0.43307973675500966, 0.222178225398995], Fitness = 1.0467649789892024
# Generation 33: Solution = [1.48419538329825, 0.09383283283939681, 0.43307973675500966, 0.222178225398995], Fitness = 1.047644777582258
# Generation 34: Solution = [1.48419538329825, 0.09383283283939681, 0.43307973675500966, 0.222178225398995], Fitness = 1.047644777582258
# Generation 35: Solution = [1.48419538329825, 0.09383283283939681, 0.43307973675500966, 0.2476212100546955], Fitness = 1.0369817724160788
# Generation 36: Solution = [1.48419538329825, 0.09383283283939681, 0.43307973675500966, 0.2842684945119651], Fitness = 1.0259636426840093
# Generation 37: Solution = [1.48419538329825, 0.09383283283939681, 0.5778386927799497, 0.2476212100546955], Fitness = 1.0169172919594123
# Generation 38: Solution = [1.48419538329825, 0.09383283283939681, 0.43307973675500966, 0.2476212100546955], Fitness = 1.0369817724160788
# Generation 39: Solution = [1.48419538329825, 0.09383283283939681, 0.43307973675500966, 0.2476212100546955], Fitness = 1.0369817724160788
# Generation 40: Solution = [1.48419538329825, 0.09383283283939681, 0.5496660030871257, 0.2476212100546955], Fitness = 1.0056867869848363
# Generation 41: Solution = [1.48419538329825, 0.09383283283939681, 0.43307973675500966, 0.32188667600749965], Fitness = 1.0201687938947224
# Generation 42: Solution = [1.48419538329825, 0.09383283283939681, 0.43307973675500966, 0.2476212100546955], Fitness = 1.0369817724160788
# Generation 43: Solution = [1.48419538329825, 0.09257993582707957, 0.43307973675500966, 0.2476212100546955], Fitness = 1.0369043439633396
# Generation 44: Solution = [1.48419538329825, 0.09383283283939681, 0.43307973675500966, 0.2476212100546955], Fitness = 1.0369817724160788
# Generation 45: Solution = [1.48419538329825, 0.09383283283939681, 0.5666042586016815, 0.2476212100546955], Fitness = 1.0119663164668358
# Generation 46: Solution = [1.48419538329825, 0.0928251086707188, 0.43307973675500966, 0.2476212100546955], Fitness = 1.0368821020538337
# Generation 47: Solution = [1.48419538329825, 0.09383283283939681, 0.43307973675500966, 0.2476212100546955], Fitness = 1.0369817724160788
# Generation 48: Solution = [1.48419538329825, 0.09383283283939681, 0.43307973675500966, 0.25767260326421515], Fitness = 1.0334424802013114
# Generation 49: Solution = [1.48419538329825, 0.09383283283939681, 0.43307973675500966, 0.30724476304394455], Fitness = 1.021749974457776
# Generation 50: Solution = [1.48419538329825, 0.09383283283939681, 0.43307973675500966, 0.3193213358288556], Fitness = 1.0203833465112095
# Generation 51: Solution = [1.48419538329825, 0.09383283283939681, 0.43307973675500966, 0.2476212100546955], Fitness = 1.0369817724160788
# Generation 52: Solution = [1.48419538329825, 0.09383283283939681, 0.43307973675500966, 0.2476212100546955], Fitness = 1.0369817724160788
# Generation 53: Solution = [1.48419538329825, 0.09383283283939681, 0.5781510150822025, 0.2476212100546955], Fitness = 1.0170626080058585
# Generation 54: Solution = [1.48419538329825, 0.09383283283939681, 0.4555825700363132, 0.2476212100546955], Fitness = 1.0166295152820528
# Generation 55: Solution = [1.48419538329825, 0.09383283283939681, 0.4555825700363132, 0.2476212100546955], Fitness = 1.0166295152820528
# Generation 56: Solution = [1.48419538329825, 0.09383283283939681, 0.44262755781874064, 0.2476212100546955], Fitness = 1.0272875458559159
# Generation 57: Solution = [1.48419538329825, 0.09383283283939681, 0.5425878356123026, 0.2476212100546955], Fitness = 1.0035651627752746
# Generation 58: Solution = [1.48419538329825, 0.09383283283939681, 0.44262755781874064, 0.2476212100546955], Fitness = 1.0272875458559159
# Generation 59: Solution = [1.48419538329825, 0.09383283283939681, 0.44262755781874064, 0.36941736482929866], Fitness = 1.0199580733304032
# Generation 60: Solution = [1.48419538329825, 0.09383283283939681, 0.44262755781874064, 0.2476212100546955], Fitness = 1.0272875458559159
# Generation 61: Solution = [1.48419538329825, 0.09383283283939681, 0.44262755781874064, 0.2476212100546955], Fitness = 1.0272875458559159
# Generation 62: Solution = [1.3330208401115702, 0.09383283283939681, 0.4855041565706131, 0.2476212100546955], Fitness = 1.0087673110024005
# Generation 63: Solution = [1.48419538329825, 0.09383283283939681, 0.44262755781874064, 0.2476212100546955], Fitness = 1.0272875458559159
# Generation 64: Solution = [1.48419538329825, 0.09383283283939681, 0.44262755781874064, 0.2476212100546955], Fitness = 1.0272875458559159
# Generation 65: Solution = [1.48419538329825, 0.09383283283939681, 0.44262755781874064, 0.2476212100546955], Fitness = 1.0272875458559159
# Generation 66: Solution = [1.48419538329825, 0.09383283283939681, 0.46292688120848324, 0.2476212100546955], Fitness = 1.0118030831388944
# Generation 67: Solution = [1.48419538329825, 0.09383283283939681, 0.44262755781874064, 0.2476212100546955], Fitness = 1.0272875458559159
# Generation 68: Solution = [1.48419538329825, 0.09383283283939681, 0.44262755781874064, 0.2476212100546955], Fitness = 1.0272875458559159
# Generation 69: Solution = [1.48419538329825, 0.09383283283939681, 0.44262755781874064, 0.2476212100546955], Fitness = 1.0272875458559159
# Generation 70: Solution = [1.48419538329825, 0.09383283283939681, 0.44262755781874064, 0.2476212100546955], Fitness = 1.0272875458559159
# Generation 71: Solution = [1.48419538329825, 0.09383283283939681, 0.44262755781874064, 0.35873072170510567], Fitness = 1.0182496110244728
# Generation 72: Solution = [1.48419538329825, 0.09383283283939681, 0.47350683116292314, 0.2476212100546955], Fitness = 1.006301048043341
# Generation 73: Solution = [1.48419538329825, 0.09383283283939681, 0.44262755781874064, 0.3553241888710461], Fitness = 1.0177989833290724
# Generation 74: Solution = [1.48419538329825, 0.09383283283939681, 0.44262755781874064, 0.29343605728695077], Fitness = 1.0176206457984998
# Generation 75: Solution = [1.48419538329825, 0.09383283283939681, 0.44262755781874064, 0.2476212100546955], Fitness = 1.0272875458559159
# Generation 76: Solution = [1.48419538329825, 0.09383283283939681, 0.44262755781874064, 0.2476212100546955], Fitness = 1.0272875458559159
# Generation 77: Solution = [1.48419538329825, 0.09383283283939681, 0.5105995559939287, 0.2476212100546955], Fitness = 0.9987357931128596
# Generation 78: Solution = [1.48419538329825, 0.09383283283939681, 0.5105995559939287, 0.2476212100546955], Fitness = 0.9987357931128596
# Generation 79: Solution = [1.48419538329825, 0.09383283283939681, 0.5105995559939287, 0.2476212100546955], Fitness = 0.9987357931128596
# Generation 80: Solution = [1.48419538329825, 0.09383283283939681, 0.5105995559939287, 0.2476212100546955], Fitness = 0.9987357931128596
# Generation 81: Solution = [1.48419538329825, 0.09383283283939681, 0.5105995559939287, 0.2476212100546955], Fitness = 0.9987357931128596
# Generation 82: Solution = [1.48419538329825, 0.09383283283939681, 0.5105995559939287, 0.2476212100546955], Fitness = 0.9987357931128596
# Generation 83: Solution = [1.452121209108229, 0.09383283283939681, 0.5105995559939287, 0.2476212100546955], Fitness = 0.994554470893932
# Generation 84: Solution = [1.3349346611840258, 0.09383283283939681, 0.5105995559939287, 0.2776234859413125], Fitness = 0.9964456827608638
# Generation 85: Solution = [1.3349346611840258, 0.09383283283939681, 0.5105995559939287, 0.2476212100546955], Fitness = 0.9970129325486525
# Generation 86: Solution = [1.40145484518724, 0.09383283283939681, 0.5105995559939287, 0.2476212100546955], Fitness = 0.9919975585541158
# Generation 87: Solution = [1.3577659737501482, 0.09383283283939681, 0.5105995559939287, 0.2476212100546955], Fitness = 0.9941460613606021
# Generation 88: Solution = [1.3349346611840258, 0.09383283283939681, 0.5105995559939287, 0.2476212100546955], Fitness = 0.9970129325486525
# Generation 89: Solution = [1.3349346611840258, 0.09383283283939681, 0.5105995559939287, 0.2476212100546955], Fitness = 0.9970129325486525
# Generation 90: Solution = [1.3349346611840258, 0.09383283283939681, 0.5105995559939287, 0.2476212100546955], Fitness = 0.9970129325486525
# Generation 91: Solution = [1.3349346611840258, 0.09383283283939681, 0.5105995559939287, 0.2476212100546955], Fitness = 0.9970129325486525
# Generation 92: Solution = [1.3349346611840258, 0.09383283283939681, 0.5105995559939287, 0.2476212100546955], Fitness = 0.9970129325486525
# Generation 93: Solution = [1.3349346611840258, 0.09383283283939681, 0.5105995559939287, 0.2476212100546955], Fitness = 0.9970129325486525
# Generation 94: Solution = [1.3349346611840258, 0.09383283283939681, 0.5105995559939287, 0.2476212100546955], Fitness = 0.9970129325486525
# Generation 95: Solution = [1.3349346611840258, 0.09383283283939681, 0.5642258257213255, 0.2476212100546955], Fitness = 0.9944192072956397
# Generation 96: Solution = [1.4402033323950467, 0.09383283283939681, 0.5105995559939287, 0.2476212100546955], Fitness = 0.9934933297136831
# Generation 97: Solution = [1.3349346611840258, 0.09383283283939681, 0.5642258257213255, 0.23096230412944752], Fitness = 0.9917358699896679
# Generation 98: Solution = [1.3349346611840258, 0.09383283283939681, 0.5642258257213255, 0.2476212100546955], Fitness = 0.9944192072956397
# Generation 99: Solution = [1.3349346611840258, 0.09383283283939681, 0.5642258257213255, 0.2476212100546955], Fitness = 0.9944192072956397
# Generation 100: Solution = [1.3349346611840258, 0.09383283283939681, 0.5642258257213255, 0.2476212100546955], Fitness = 0.9944192072956397
# Generation 101: Solution = [1.3349346611840258, 0.09383283283939681, 0.5642258257213255, 0.2476212100546955], Fitness = 0.9944192072956397
# Generation 102: Solution = [1.3349346611840258, 0.09383283283939681, 0.5642258257213255, 0.14295921627983832], Fitness = 0.9921155989313829
# Generation 103: Solution = [1.3349346611840258, 0.09383283283939681, 0.5642258257213255, 0.2476212100546955], Fitness = 0.9944192072956397
# Generation 104: Solution = [1.3349346611840258, 0.09383283283939681, 0.5642258257213255, 0.2476212100546955], Fitness = 0.9944192072956397
# Generation 105: Solution = [1.3349346611840258, 0.09383283283939681, 0.5502127135338366, 0.2476212100546955], Fitness = 0.9928732000657721
# Generation 106: Solution = [1.3349346611840258, 0.09383283283939681, 0.5642258257213255, 0.2476212100546955], Fitness = 0.9944192072956397
# Generation 107: Solution = [1.3349346611840258, 0.09383283283939681, 0.5642258257213255, 0.2476212100546955], Fitness = 0.9944192072956397
# Generation 108: Solution = [1.3349346611840258, 0.09383283283939681, 0.5642258257213255, 0.2476212100546955], Fitness = 0.9944192072956397
# Generation 109: Solution = [1.3349346611840258, 0.09383283283939681, 0.5642258257213255, 0.16752269904490635], Fitness = 0.9894172865150915
# Generation 110: Solution = [1.3501235426738374, 0.09383283283939681, 0.5642258257213255, 0.2476212100546955], Fitness = 0.9939588382724278
# Generation 111: Solution = [1.3349346611840258, 0.09383283283939681, 0.5642258257213255, 0.1743996502539238], Fitness = 0.9890333952347495
# Generation 112: Solution = [1.3349346611840258, 0.09383283283939681, 0.5642258257213255, 0.1978079266927959], Fitness = 0.9889085051414942
# Generation 113: Solution = [1.3349346611840258, 0.09383283283939681, 0.5642258257213255, 0.2476212100546955], Fitness = 0.9944192072956397
# Generation 114: Solution = [1.1252224197909904, 0.09383283283939681, 0.5642258257213255, 0.2476212100546955], Fitness = 1.0661890939087963
# Generation 115: Solution = [0.8360913228249587, 0.09383283283939681, 1.240227568458459, 0.5723173310207914], Fitness = 1.2026359246570661
# Generation 116: Solution = [1.2003233261814512, 0.09383283283939681, 0.3262206770739535, 0.5723173310207914], Fitness = 1.138002566231413
# Generation 117: Solution = [1.2475944626761195, 0.09383283283939681, 0.6108322364226291, 0.5723173310207914], Fitness = 1.1668874238400966
# Generation 118: Solution = [0.8360913228249587, 0.1370641354151576, 0.6108322364226291, 0.5723173310207914], Fitness = 1.1392561110903439
# Generation 119: Solution = [0.8360913228249587, 0.09383283283939681, 1.5614167692696816, 0.0522240044281117], Fitness = 1.1374785109004102
# Generation 120: Solution = [1.2744951926186139, 0.09383283283939681, 0.7358317037577609, 0.5723173310207914], Fitness = 1.1933704285825937
# Generation 121: Solution = [1.2744951926186139, 0.09383283283939681, 0.40454536315346346, 0.3516836536338417], Fitness = 1.0662828474606814
# Generation 122: Solution = [1.2836419509780908, 0.09383283283939681, 0.40454536315346346, 0.5723173310207914], Fitness = 1.0744079228596912
# Generation 123: Solution = [1.2744951926186139, 0.09383283283939681, 0.40454536315346346, 0.5723173310207914], Fitness = 1.0753678865915821
# Generation 124: Solution = [1.2744951926186139, 0.09383283283939681, 0.40454536315346346, 0.5723173310207914], Fitness = 1.0753678865915821
# Generation 125: Solution = [1.2744951926186139, 0.09383283283939681, 0.40454536315346346, 0.5723173310207914], Fitness = 1.0753678865915821
# Generation 126: Solution = [1.2744951926186139, 0.09383283283939681, 0.40454536315346346, 0.5371987482500671], Fitness = 1.0567554374684591
# Generation 127: Solution = [1.351770117233131, 0.09383283283939681, 0.40454536315346346, 0.5723173310207914], Fitness = 1.0738018396632227
# Generation 128: Solution = [1.3684541006924376, 0.09383283283939681, 0.40454536315346346, 0.5723173310207914], Fitness = 1.0752916008120676
# Generation 129: Solution = [1.2744951926186139, 0.09581332179437574, 0.40454536315346346, 0.5723173310207914], Fitness = 1.0707661727831654
# Generation 130: Solution = [1.2744951926186139, 0.09581332179437574, 0.40454536315346346, 0.5723173310207914], Fitness = 1.0707661727831654
# Generation 131: Solution = [1.2744951926186139, 0.09581332179437574, 0.40454536315346346, 0.350062502094207], Fitness = 1.0600920234799736
# Generation 132: Solution = [1.2744951926186139, 0.09581332179437574, 0.40454536315346346, 0.5723173310207914], Fitness = 1.0707661727831654
# Generation 133: Solution = [1.2744951926186139, 0.09581332179437574, 0.40454536315346346, 0.44666902285550636], Fitness = 1.0333643770171432
# Generation 134: Solution = [1.3197623034657922, 0.09581332179437574, 0.40454536315346346, 0.5723173310207914], Fitness = 1.0700403988043279
# Generation 135: Solution = [1.2744951926186139, 0.09581332179437574, 0.3784504406633935, 0.5723173310207914], Fitness = 1.06835508499012
# Generation 136: Solution = [1.2744951926186139, 0.09581332179437574, 0.40454536315346346, 0.5723173310207914], Fitness = 1.0707661727831654
# Generation 137: Solution = [1.2744951926186139, 0.09581332179437574, 0.40454536315346346, 0.5723173310207914], Fitness = 1.0707661727831654
# Generation 138: Solution = [1.2744951926186139, 0.09581332179437574, 0.4007597787489259, 0.5723173310207914], Fitness = 1.06996890346269
# Generation 139: Solution = [1.2744951926186139, 0.09581332179437574, 0.40454536315346346, 0.5723173310207914], Fitness = 1.0707661727831654
# Generation 140: Solution = [1.2744951926186139, 0.09581332179437574, 0.40454536315346346, 0.39424414710860756], Fitness = 1.0421040782087256
# Generation 141: Solution = [1.2744951926186139, 0.09581332179437574, 0.40454536315346346, 0.5235104680327451], Fitness = 1.0464328321240537
# Generation 142: Solution = [1.2744951926186139, 0.09581332179437574, 0.40454536315346346, 0.5723173310207914], Fitness = 1.0707661727831654
# Generation 143: Solution = [1.2744951926186139, 0.09581332179437574, 0.40454536315346346, 0.5723173310207914], Fitness = 1.0707661727831654
# Generation 144: Solution = [1.2950615301106476, 0.09581332179437574, 0.40454536315346346, 0.5723173310207914], Fitness = 1.0698037832325606
# Generation 145: Solution = [1.2744951926186139, 0.09581332179437574, 0.40454536315346346, 0.5723173310207914], Fitness = 1.0707661727831654
# Generation 146: Solution = [1.2744951926186139, 0.09581332179437574, 0.40454536315346346, 0.5723173310207914], Fitness = 1.0707661727831654
# Generation 147: Solution = [1.2744951926186139, 0.09581332179437574, 0.40454536315346346, 0.43592177403519194], Fitness = 1.034005112653141
# Generation 148: Solution = [1.2744951926186139, 0.09581332179437574, 0.40454536315346346, 0.5723173310207914], Fitness = 1.0707661727831654
# Generation 149: Solution = [1.279367443837469, 0.09581332179437574, 0.40454536315346346, 0.5723173310207914], Fitness = 1.0704399539393132
# Generation 150: Solution = [1.2744951926186139, 0.09581332179437574, 0.40454536315346346, 0.5723173310207914], Fitness = 1.0707661727831654
# Generation 151: Solution = [1.2013907452082264, 0.09581332179437574, 0.40454536315346346, 0.42527181239522505], Fitness = 1.0607981544029492
# Generation 152: Solution = [1.2744951926186139, 0.09581332179437574, 0.40454536315346346, 0.5723173310207914], Fitness = 1.0707661727831654
# Generation 153: Solution = [1.2744951926186139, 0.09581332179437574, 0.40454536315346346, 0.3826718261324926], Fitness = 1.0459031359262583
# Generation 154: Solution = [1.2744951926186139, 0.09581332179437574, 0.40454536315346346, 0.3842377217747117], Fitness = 1.0453504901292758
# Generation 155: Solution = [1.2744951926186139, 0.09581332179437574, 0.40454536315346346, 0.4148695395031692], Fitness = 1.0369905535738249
# Generation 156: Solution = [1.3266705410869044, 0.09581332179437574, 0.40454536315346346, 0.5723173310207914], Fitness = 1.0703678180044274
# Generation 157: Solution = [1.3266705410869044, 0.09581332179437574, 0.40454536315346346, 0.5723173310207914], Fitness = 1.0703678180044274
# Generation 158: Solution = [1.3266705410869044, 0.09581332179437574, 0.3791086280358571, 0.5723173310207914], Fitness = 1.0647536479673967
# Generation 159: Solution = [1.3266705410869044, 0.09581332179437574, 0.40454536315346346, 0.5723173310207914], Fitness = 1.0703678180044274
# Generation 160: Solution = [1.3266705410869044, 0.09581332179437574, 0.40454536315346346, 0.5723173310207914], Fitness = 1.0703678180044274
# Generation 161: Solution = [1.3266705410869044, 0.09581332179437574, 0.48895510427012456, 0.3184188234704326], Fitness = 0.9990970828950169
# Generation 162: Solution = [1.3266705410869044, 0.09581332179437574, 0.3702205612768863, 0.5723173310207914], Fitness = 1.064615829401466
# Generation 163: Solution = [1.3266705410869044, 0.09581332179437574, 0.569903883214343, 0.31204158789370173], Fitness = 1.0116438693023755
# Generation 164: Solution = [1.3266705410869044, 0.09581332179437574, 0.569903883214343, 0.38266719281249895], Fitness = 1.042604754004033
# Generation 165: Solution = [1.3266705410869044, 0.09581332179437574, 0.569903883214343, 0.2996544571509743], Fitness = 1.0073163224430732
# Generation 166: Solution = [1.3266705410869044, 0.09581332179437574, 0.28717373885616504, 0.5796837885426163], Fitness = 1.1531941624014688
# Generation 167: Solution = [1.3266705410869044, 0.09581332179437574, 0.4721076508036266, 0.5723173310207914], Fitness = 1.1048983293732846
# Generation 168: Solution = [1.3266705410869044, 0.09581332179437574, 0.4589093977621921, 0.5723173310207914], Fitness = 1.0970532027668929
# Generation 169: Solution = [1.3266705410869044, 0.09581332179437574, 0.28717373885616504, 0.5723173310207914], Fitness = 1.1541789145542884
# Generation 170: Solution = [1.3266705410869044, 0.09581332179437574, 0.33992314693133174, 0.47074955977372146], Fitness = 1.083513839176187
# Generation 171: Solution = [1.5416434088161743, 0.09581332179437574, 0.28717373885616504, 0.5723173310207914], Fitness = 1.1380582482344361
# Generation 172: Solution = [1.4250044227227283, 0.09581332179437574, 0.28717373885616504, 0.5723173310207914], Fitness = 1.134794985298095
# Generation 173: Solution = [1.3266705410869044, 0.09581332179437574, 0.4464163897553364, 0.5723173310207914], Fitness = 1.0899178444978017
# Generation 174: Solution = [1.3628624248583012, 0.09581332179437574, 0.28717373885616504, 0.5723173310207914], Fitness = 1.144384686270747
# Generation 175: Solution = [1.3266705410869044, 0.09581332179437574, 0.43983716134828654, 0.5723173310207914], Fitness = 1.0863257889336635
# Generation 176: Solution = [1.3266705410869044, 0.09581332179437574, 0.28717373885616504, 0.5723173310207914], Fitness = 1.1541789145542884
# Generation 177: Solution = [1.505167019075349, 0.09581332179437574, 0.28717373885616504, 0.5723173310207914], Fitness = 1.1343374294639317
# Generation 178: Solution = [1.605189730629726, 0.09581332179437574, 0.28717373885616504, 0.5723173310207914], Fitness = 1.1497439615551566
# Generation 179: Solution = [1.3266705410869044, 0.09581332179437574, 0.544082887531161, 0.5723173310207914], Fitness = 1.1478953089467123
# Generation 180: Solution = [1.3266705410869044, 0.09581332179437574, 0.28717373885616504, 0.5723173310207914], Fitness = 1.1541789145542884
# Generation 181: Solution = [1.5214911330764227, 0.09581332179437574, 0.2788071607861895, 0.5723173310207914], Fitness = 1.1517864657320245
# Generation 182: Solution = [1.3266705410869044, 0.09581332179437574, 0.40306940702783334, 0.5723173310207914], Fitness = 1.0698716226414908
# Generation 183: Solution = [1.3266705410869044, 0.09581332179437574, 0.40490836976048983, 0.37000450243396443], Fitness = 1.0368894782241793
# Generation 184: Solution = [1.3266705410869044, 0.09581332179437574, 0.40490836976048983, 0.5723173310207914], Fitness = 1.0704925379287573
# Generation 185: Solution = [1.3266705410869044, 0.09581332179437574, 0.40490836976048983, 0.5723173310207914], Fitness = 1.0704925379287573
# Generation 186: Solution = [1.3266705410869044, 0.09581332179437574, 0.40490836976048983, 0.5723173310207914], Fitness = 1.0704925379287573
# Generation 187: Solution = [1.2944996712269004, 0.09581332179437574, 0.40490836976048983, 0.5723173310207914], Fitness = 1.0699150879234691
# Generation 188: Solution = [1.3266705410869044, 0.09581332179437574, 0.40490836976048983, 0.4181978418545105], Fitness = 1.0265195898990838
# Generation 189: Solution = [1.3266705410869044, 0.09581332179437574, 0.40490836976048983, 0.5723173310207914], Fitness = 1.0704925379287573
# Generation 190: Solution = [1.3266705410869044, 0.09581332179437574, 0.40490836976048983, 0.46552378402548933], Fitness = 1.0274023178340155
# Generation 191: Solution = [1.3266705410869044, 0.09581332179437574, 0.5792755125490676, 0.21017185329845667], Fitness = 0.9884620390809267
# Generation 192: Solution = [1.3266705410869044, 0.09581332179437574, 0.8748707034135861, 0.21017185329845667], Fitness = 1.083422099223265
# Generation 193: Solution = [1.3266705410869044, 0.09581332179437574, 0.5076732025717363, 0.21017185329845667], Fitness = 1.0023023159445847
# Generation 194: Solution = [1.3266705410869044, 0.09581332179437574, 0.5076732025717363, 0.21017185329845667], Fitness = 1.0023023159445847
# Generation 195: Solution = [1.3266705410869044, 0.09581332179437574, 0.5076732025717363, 0.2979371766578014], Fitness = 0.9959476151684801
# Generation 196: Solution = [1.3266705410869044, 0.09581332179437574, 0.5076732025717363, 0.23906952021469086], Fitness = 0.9970159225017723
# Generation 197: Solution = [1.3266705410869044, 0.09581332179437574, 0.5076732025717363, 0.21017185329845667], Fitness = 1.0023023159445847
# Generation 198: Solution = [1.3266705410869044, 0.09581332179437574, 0.5076732025717363, 0.21017185329845667], Fitness = 1.0023023159445847
# Generation 199: Solution = [1.3266705410869044, 0.09581332179437574, 0.5076732025717363, 0.21017185329845667], Fitness = 1.0023023159445847
# Generation 200: Solution = [1.3266705410869044, 0.09581332179437574, 0.5076732025717363, 0.21017185329845667], Fitness = 1.0023023159445847
# Generation 201: Solution = [1.3266705410869044, 0.09581332179437574, 0.5220228550625547, 0.21017185329845667], Fitness = 0.9954672121335091
# Generation 202: Solution = [1.3266705410869044, 0.09748035421871881, 0.5076732025717363, 0.21017185329845667], Fitness = 1.0001027229113137
# Generation 203: Solution = [1.3266705410869044, 0.09581332179437574, 0.615483835444304, 0.21017185329845667], Fitness = 0.9953418289027979
# Generation 204: Solution = [1.3266705410869044, 0.09581332179437574, 0.615483835444304, 0.08971318141974671], Fitness = 0.9846138261199806
# Generation 205: Solution = [1.3266705410869044, 0.09581332179437574, 0.5740448656011898, 0.2375962478341762], Fitness = 0.9920983644929157
# Generation 206: Solution = [1.3266705410869044, 0.09581332179437574, 0.615483835444304, 0.21017185329845667], Fitness = 0.9953418289027979
# Generation 207: Solution = [1.3266705410869044, 0.09581332179437574, 0.615483835444304, 0.1654618927743614], Fitness = 0.9867811050418491
# Generation 208: Solution = [1.3266705410869044, 0.09581332179437574, 0.615483835444304, 0.21017185329845667], Fitness = 0.9953418289027979
# Generation 209: Solution = [1.3266705410869044, 0.09581332179437574, 0.615483835444304, 0.06229718992831512], Fitness = 0.9880689246785828
# Generation 210: Solution = [1.3266705410869044, 0.09581332179437574, 0.615483835444304, 0.21017185329845667], Fitness = 0.9953418289027979
# Generation 211: Solution = [1.3266705410869044, 0.09581332179437574, 0.572464703284775, 0.21017185329845667], Fitness = 0.987946790920373
# Generation 212: Solution = [1.3266705410869044, 0.09581332179437574, 0.615483835444304, 0.21017185329845667], Fitness = 0.9953418289027979
# Generation 213: Solution = [1.3266705410869044, 0.09581332179437574, 0.615483835444304, 0.21017185329845667], Fitness = 0.9953418289027979
# Generation 214: Solution = [1.3266705410869044, 0.09581332179437574, 0.615483835444304, 0.21017185329845667], Fitness = 0.9953418289027979
# Generation 215: Solution = [1.3266705410869044, 0.09581332179437574, 0.615483835444304, 0.17543468388185235], Fitness = 0.9882538570268117
# Generation 216: Solution = [1.3266705410869044, 0.09581332179437574, 0.615483835444304, 0.21017185329845667], Fitness = 0.9953418289027979
# Generation 217: Solution = [1.3266705410869044, 0.09581332179437574, 0.5639842009120541, 0.21017185329845667], Fitness = 0.9877344704958649
# Generation 218: Solution = [1.3266705410869044, 0.09581332179437574, 0.615483835444304, 0.19568534074781674], Fitness = 0.9920259804909837
# Generation 219: Solution = [1.3266705410869044, 0.09581332179437574, 0.5440900269422695, 0.21017185329845667], Fitness = 0.9893872213076774
# Generation 220: Solution = [1.3266705410869044, 0.09581332179437574, 0.610328689901809, 0.19568534074781674], Fitness = 0.990905764896807
# Generation 221: Solution = [1.3266705410869044, 0.09581332179437574, 0.615483835444304, 0.19568534074781674], Fitness = 0.9920259804909837
# Generation 222: Solution = [1.3266705410869044, 0.09581332179437574, 0.615483835444304, 0.05861652787687821], Fitness = 0.9887151617118378
# Generation 223: Solution = [1.3266705410869044, 0.09581332179437574, 0.615483835444304, 0.19568534074781674], Fitness = 0.9920259804909837
# Generation 224: Solution = [1.3266705410869044, 0.09581332179437574, 0.615483835444304, 0.19568534074781674], Fitness = 0.9920259804909837
# Generation 225: Solution = [1.3266705410869044, 0.09581332179437574, 0.615483835444304, 0.19568534074781674], Fitness = 0.9920259804909837
# Generation 226: Solution = [1.3266705410869044, 0.09581332179437574, 0.615483835444304, 0.05016568322683712], Fitness = 0.990365491415309
# Generation 227: Solution = [1.3266705410869044, 0.09581332179437574, 0.615483835444304, 0.19568534074781674], Fitness = 0.9920259804909837
# Generation 228: Solution = [1.3266705410869044, 0.09581332179437574, 0.615483835444304, 0.19568534074781674], Fitness = 0.9920259804909837
# Generation 229: Solution = [1.3266705410869044, 0.09581332179437574, 0.615483835444304, 0.19568534074781674], Fitness = 0.9920259804909837
# Generation 230: Solution = [1.3266705410869044, 0.09581332179437574, 0.615483835444304, 0.1856385740008546], Fitness = 0.9900259346514162
# Generation 231: Solution = [1.3266705410869044, 0.09581332179437574, 0.615483835444304, 0.19568534074781674], Fitness = 0.9920259804909837
# Generation 232: Solution = [1.3266705410869044, 0.09581332179437574, 0.615483835444304, 0.19568534074781674], Fitness = 0.9920259804909837
# Generation 233: Solution = [1.3266705410869044, 0.09581332179437574, 0.615483835444304, 0.12180032511441041], Fitness = 0.9835098181775416
# Generation 234: Solution = [1.3266705410869044, 0.09581332179437574, 0.615483835444304, 0.07984996554482326], Fitness = 0.9855839623560642
# Generation 235: Solution = [1.3266705410869044, 0.09581332179437574, 0.5651549995599425, 0.19568534074781674], Fitness = 0.9870350232136127
# Generation 236: Solution = [1.3266705410869044, 0.09581332179437574, 0.5651549995599425, 0.19568534074781674], Fitness = 0.9870350232136127
# Generation 237: Solution = [1.3266705410869044, 0.09581332179437574, 0.5651549995599425, 0.19568534074781674], Fitness = 0.9870350232136127
# Generation 238: Solution = [1.3266705410869044, 0.09581332179437574, 0.8726258395953963, 0.0722044407525202], Fitness = 1.0335363093519518
# Generation 239: Solution = [1.3266705410869044, 0.09581332179437574, 0.8726258395953963, 0.03373545524177657], Fitness = 1.021898779438732
# Generation 240: Solution = [1.3266705410869044, 0.09581332179437574, 0.8726258395953963, 0.013060481601586016], Fitness = 1.0161476229564457
# Generation 241: Solution = [1.1703446803982094, 0.09581332179437574, 0.8726258395953963, 0.19568534074781674], Fitness = 1.0557126975528994
# Generation 242: Solution = [1.3266705410869044, 0.09581332179437574, 0.5893944645090514, 0.19568534074781674], Fitness = 0.9876269135510873
# Generation 243: Solution = [1.3266705410869044, 0.09581332179437574, 0.8726258395953963, 0.03991958812894092], Fitness = 1.0236903339040686
# Generation 244: Solution = [1.3266705410869044, 0.09581332179437574, 0.8726258395953963, 0.19502601971403877], Fitness = 1.0769901020039634
# Generation 245: Solution = [1.3266705410869044, 0.09581332179437574, 0.8726258395953963, 0.19064462967772555], Fitness = 1.0753133955784049
# Generation 246: Solution = [1.3266705410869044, 0.09581332179437574, 0.8726258395953963, 0.19568534074781674], Fitness = 1.0772430525725905
# Generation 247: Solution = [1.3266705410869044, 0.09581332179437574, 0.8726258395953963, 0.01462488231834902], Fitness = 1.0165695347073729
# Generation 248: Solution = [1.3266705410869044, 0.09581332179437574, 0.8726258395953963, 0.06280983830000442], Fitness = 1.0305892264678933
# Generation 249: Solution = [1.3266705410869044, 0.09581332179437574, 0.5642091337480319, 0.19568534074781674], Fitness = 0.9870959344376498
# Generation 250: Solution = [1.3266705410869044, 0.09581332179437574, 0.8726258395953963, 0.09438050198390902], Fitness = 1.0407397836911154
# Generation 251: Solution = [1.3266705410869044, 0.09581332179437574, 0.5792628669285362, 0.09438050198390902], Fitness = 0.9945370786054233
# Generation 252: Solution = [1.324687968532964, 0.09581332179437574, 0.8726258395953963, 0.09438050198390902], Fitness = 1.0402943989037123
# Generation 253: Solution = [1.3266705410869044, 0.09581332179437574, 0.8726258395953963, 0.08217891253344356], Fitness = 1.0367346370086064
# Generation 254: Solution = [1.3266705410869044, 0.09581332179437574, 0.7578175500550228, 0.09438050198390902], Fitness = 1.0072922534736013
# Generation 255: Solution = [1.159344288348565, 0.09581332179437574, 0.8726258395953963, 0.09438050198390902], Fitness = 1.0380001936455392
# Generation 256: Solution = [1.3266705410869044, 0.09581332179437574, 0.7368323280308506, 0.09438050198390902], Fitness = 1.0010297461442994
# Generation 257: Solution = [1.159344288348565, 0.09581332179437574, 0.7154725376396363, 0.09438050198390902], Fitness = 1.0300949343518124
# Generation 258: Solution = [1.2466886454844208, 0.09581332179437574, 0.8726258395953963, 0.09438050198390902], Fitness = 1.0300754220621433
# Generation 259: Solution = [1.1644814813267192, 0.09581332179437574, 0.8726258395953963, 0.03588625458244543], Fitness = 1.029181600491634
# Generation 260: Solution = [1.1644814813267192, 0.09581332179437574, 0.7066353910679988, 0.09438050198390902], Fitness = 1.0277339104019505
# Generation 261: Solution = [1.1644814813267192, 0.09581332179437574, 0.7361960489597763, 0.09438050198390902], Fitness = 1.0283821948252057
# Generation 262: Solution = [1.2061996718179444, 0.09581332179437574, 0.8726258395953963, 0.09438050198390902], Fitness = 1.0309549095571349
# Generation 263: Solution = [1.1644814813267192, 0.09581332179437574, 0.8726258395953963, 0.09438050198390902], Fitness = 1.036890074178161
# Generation 264: Solution = [1.1644814813267192, 0.09581332179437574, 0.8726258395953963, 0.037020656088634585], Fitness = 1.0293018107183682
# Generation 265: Solution = [1.1644814813267192, 0.09581332179437574, 0.7160204753335488, 0.09438050198390902], Fitness = 1.0277528898085246
# Generation 266: Solution = [1.1644814813267192, 0.09581332179437574, 0.7132301100346103, 0.09438050198390902], Fitness = 1.027726144837609
# Generation 267: Solution = [1.1644814813267192, 0.09581332179437574, 0.8726258395953963, 0.09438050198390902], Fitness = 1.036890074178161
# Generation 268: Solution = [1.1951930385732057, 0.09581332179437574, 0.8726258395953963, 0.09438050198390902], Fitness = 1.0320039453474092
# Generation 269: Solution = [1.1644814813267192, 0.09581332179437574, 0.8726258395953963, 0.09438050198390902], Fitness = 1.036890074178161
# Generation 270: Solution = [1.1644814813267192, 0.09581332179437574, 0.8726258395953963, 0.09438050198390902], Fitness = 1.036890074178161
# Generation 271: Solution = [1.1644814813267192, 0.12067005033249711, 0.8726258395953963, 0.09438050198390902], Fitness = 1.0301112725260144
# Generation 272: Solution = [1.1644814813267192, 0.09581332179437574, 0.7587510325013849, 0.09438050198390902], Fitness = 1.029719410242272
# Generation 273: Solution = [1.3059007604063393, 0.09581332179437574, 0.8726258395953963, 0.09438050198390902], Fitness = 1.0365095818826273
# Generation 274: Solution = [1.1644814813267192, 0.10955408799049904, 0.8726258395953963, 0.09438050198390902], Fitness = 1.017134601422505
# Generation 275: Solution = [1.1644814813267192, 0.10955408799049904, 0.8726258395953963, 0.09438050198390902], Fitness = 1.017134601422505
# Generation 276: Solution = [1.1644814813267192, 0.10955408799049904, 0.8726258395953963, 0.09438050198390902], Fitness = 1.017134601422505
# Generation 277: Solution = [1.1644814813267192, 0.10955408799049904, 0.8726258395953963, 0.07475173405990931], Fitness = 1.0134503624414604
# Generation 278: Solution = [1.1644814813267192, 0.10955408799049904, 0.6560150847486164, 0.09438050198390902], Fitness = 0.9961379664084138
# Generation 279: Solution = [1.1644814813267192, 0.10955408799049904, 0.8726258395953963, 0.09438050198390902], Fitness = 1.017134601422505
# Generation 280: Solution = [1.1644814813267192, 0.10955408799049904, 0.8726258395953963, 0.09438050198390902], Fitness = 1.017134601422505
# Generation 281: Solution = [1.1644814813267192, 0.10955408799049904, 0.8726258395953963, 0.09438050198390902], Fitness = 1.017134601422505
# Generation 282: Solution = [1.1644814813267192, 0.10955408799049904, 0.8726258395953963, 0.09438050198390902], Fitness = 1.017134601422505
# Generation 283: Solution = [1.1469713685823384, 0.10955408799049904, 0.8726258395953963, 0.09438050198390902], Fitness = 1.0160745866761216
# Generation 284: Solution = [1.1644814813267192, 0.10955408799049904, 0.7874851092654971, 0.09438050198390902], Fitness = 1.0040343902461986
# Generation 285: Solution = [1.1644814813267192, 0.10955408799049904, 0.736068877111981, 0.09438050198390902], Fitness = 0.9970222390525387
# Generation 286: Solution = [1.1644814813267192, 0.10955408799049904, 0.8726258395953963, 0.09438050198390902], Fitness = 1.017134601422505
# Generation 287: Solution = [1.1644814813267192, 0.10955408799049904, 0.8726258395953963, 0.07769314041482822], Fitness = 1.0139818427082852
# Generation 288: Solution = [1.1644814813267192, 0.10955408799049904, 0.8726258395953963, 0.09438050198390902], Fitness = 1.017134601422505
# Generation 289: Solution = [1.1644814813267192, 0.10955408799049904, 0.8368871550126029, 0.09438050198390902], Fitness = 1.0117379542410512
# Generation 290: Solution = [1.2971771743384262, 0.10955408799049904, 0.8726258395953963, 0.09438050198390902], Fitness = 1.0523264321512902
# Generation 291: Solution = [1.6231779145009828, 0.10955408799049904, 0.6409304224807051, 0.09438050198390902], Fitness = 1.1233053777963602
# Generation 292: Solution = [1.2931141432816309, 0.10955408799049904, 0.8726258395953963, 0.09438050198390902], Fitness = 1.0506192437981208
# Generation 293: Solution = [1.6552631024391984, 0.10955408799049904, 0.8726258395953963, 0.09438050198390902], Fitness = 1.3102570757024439
# Generation 294: Solution = [1.6552631024391984, 0.10955408799049904, 0.702261443659737, 0.09438050198390902], Fitness = 1.1855142649613148
# Generation 295: Solution = [1.0332044272779541, 0.10955408799049904, 0.8726258395953963, 0.09438050198390902], Fitness = 1.034771961377465
# Generation 296: Solution = [1.139691316882459, 0.10955408799049904, 0.8726258395953963, 0.09438050198390902], Fitness = 1.0159142844793734
# Generation 297: Solution = [1.3076342991342425, 0.10955408799049904, 0.8726258395953963, 0.09438050198390902], Fitness = 1.0568823983292526
# Generation 298: Solution = [1.6552631024391984, 0.10955408799049904, 0.8726258395953963, 0.09438050198390902], Fitness = 1.3102570757024439
# Generation 299: Solution = [1.6552631024391984, 0.10955408799049904, 0.6010548647057163, 0.09438050198390902], Fitness = 1.124652328442725
# Generation 300: Solution = [1.6552631024391984, 0.10955408799049904, 0.7808506114559244, 0.09438050198390902], Fitness = 1.2432251302909951
# Best Solution: [1.4677604086358, 0.09383283283939681, 0.6032874229835683, 0.09009672607447738]
# Best Fitness: 0.9812045349365947

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load the datasets (adjust the file paths as necessary)
standing_file_path = r'C:\Users\Onyeka\Downloads\Fitts_Law_Dataset.xlsx'
sitting_file_path = r'C:\Users\Onyeka\Downloads\SittingCondition.xlsx'

# Load the data for standing condition
standing_data = pd.read_excel(standing_file_path)

# Clean column names (remove leading/trailing whitespace)
standing_data.columns = standing_data.columns.str.strip()

# Create a new column for combined quadrant information for easier plotting
standing_data['Quadrant'] = standing_data['HQuadrant'].astype(str) + '-' + standing_data['VQuadrant'].astype(str)

# Map the combined quadrant labels to simple Q1, Q2, Q3, Q4
quadrant_order = ['1-1', '1-2', '2-1', '2-2', '3-1', '3-2', '4-1', '4-2']
quadrant_labels = ['Q1', 'Q2', 'Q3', 'Q4']

# Create a mapping from the combined quadrant labels to simple Q1, Q2, etc.
label_mapping = {quadrant: label for quadrant, label in zip(quadrant_order, quadrant_labels)}

# Map the labels to the data
standing_data['QuadrantLabel'] = standing_data['Quadrant'].map(label_mapping)

# Calculate the absolute error for standing condition
standing_data['AbsoluteError'] = abs(standing_data['InteractionTime'] - standing_data['InteractionTime'].mean())

# Load the data for sitting condition
sitting_data = pd.read_excel(sitting_file_path)

# Clean column names (remove leading/trailing whitespace)
sitting_data.columns = sitting_data.columns.str.strip()

# Create a new column for combined quadrant information for easier plotting
sitting_data['Quadrant'] = sitting_data['HQuadrant'].astype(str) + '-' + sitting_data['VQuadrant'].astype(str)

# Map the labels to the data
sitting_data['QuadrantLabel'] = sitting_data['Quadrant'].map(label_mapping)

# Calculate the absolute error for sitting condition
sitting_data['AbsoluteError'] = abs(sitting_data['InteractionTime'] - sitting_data['InteractionTime'].mean())

# Plotting the boxplots for both conditions
fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(12, 12))

# Standing condition plot
sns.boxplot(x='QuadrantLabel', y='AbsoluteError', data=standing_data, order=quadrant_labels, ax=axes[0])
axes[0].set_title('Boxplot of Absolute Error by Quadrant in Standing Condition', fontsize=22)
axes[0].set_xlabel('Quadrants', fontsize=20)
axes[0].set_ylabel('Absolute Error', fontsize=20)
axes[0].tick_params(axis='x', labelsize=20)
axes[0].tick_params(axis='y', labelsize=20)

# Sitting condition plot
sns.boxplot(x='QuadrantLabel', y='AbsoluteError', data=sitting_data, order=quadrant_labels, ax=axes[1])
axes[1].set_title('Boxplot of Absolute Error by Quadrant in Sitting Condition', fontsize=22)
axes[1].set_xlabel('Quadrants', fontsize=20)
axes[1].set_ylabel('Absolute Error', fontsize=20)
axes[1].tick_params(axis='x', labelsize=20)
axes[1].tick_params(axis='y', labelsize=20)

# Adjust layout to prevent overlap
plt.tight_layout()

# Save the combined plot as an EPS file
plt.savefig(r'C:\Users\Onyeka\Downloads\Doctoral School\combined_boxplot_absolute_error_by_quadrant.eps', format='eps')

plt.show()
